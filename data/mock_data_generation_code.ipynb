# %% [markdown]
# # Mock data generation

# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_excel('mock_random.xlsx')

# %% [markdown]
# # 1. Generate a random dataset (without error)

# %% [markdown]
# ## Setting

# %% [markdown]
# - 2 years (2017, 2018)
# - 3 grades each year (1, 2, 3)
# - 1000 students each grade
# - Each student ranks 5 schools
# - 25 schools
# - Capacity at each school: random between 50 - 60
# - 2 tie-breaker student groups (0, 1)
# - 3 types of advantage (0.1, 0.3, 0.5) applied to student group 1
# - Priority: random among (0,1,2,3,4,5)
# - Priority = 0: guaranteed assignment
# - Outcome 1,2, Covariate 1,2: student-specific
# - Covariate 3: stduent-school specific (e.g. distance)

# %%
# Define the parameters

years = [2017, 2018]
grades = [1,2,3]
num_students_per_grade = 1000
num_schools = 25
max_num_schools_per_student = 5
num_tie_breakers = 20

# %%
# studnet-specific information

num_total_students = len(years) * len(grades) * num_students_per_grade
all_students = list(range(1, num_total_students + 1))
random.shuffle(all_students)

# default tie-breaker value
tie_dict = {}
for n in range(1, num_total_students+1):
    tie_dict[n] = {}
    for t in range(1, num_tie_breakers+1):
        tie_dict[n][t] = random.uniform(0, 1)
            
# outcomes 1, 2
outcome_dict = {}
for n in range(1, num_total_students+1):
    outcome_dict[n] = {}
    outcome_dict[n] = (random.randint(0, 100), random.randint(0, 100))

# covariate 1, 2
covariate_dict = {}
for n in range(1, num_total_students+1):
    covariate_dict[n] = {}
    covariate_dict[n] = (random.randint(0, 100), random.randint(0, 100))

# %%
# (school, year, grade) - speicific information

#capacity
capacity_dict = {}
for n in range(1, num_schools+1):
    capacity_dict[n] = {}
    for y in years:
        capacity_dict[n][y] = {}
        for g in grades:
            capacity_dict[n][y][g] = random.randint(50,60)

# treatment
treatment_dict = {}
for n in range(1, num_schools+1):
    treatment_dict[n] = {}
    for y in years:
        treatment_dict[n][y] = {}
        for g in grades:
            treatment_dict[n][y][g] = random.randint(0, 1)
            
# advantage
advantage_dict = {}
for n in range(1, num_schools+1):
    advantage_dict[n] = {}
    for y in years:
        advantage_dict[n][y] = {}
        for g in grades:
            advantage_dict[n][y][g] = random.choice([0.1, 0.3, 0.5])

# %%
# student - school pair specific information

# covariate 3 (e.g., distance)
covariate3_dict = {}
for n in range(1, num_total_students+1):
    covariate3_dict[n] = {}
    for s in range(1, num_schools+1):
        covariate3_dict[n][s] = random.randint(10, 500)

# %%
# Define the column names
columns = ['Student ID', 'Year', 'Grade', 'Choice Rank', 'School ID', 'Treatment', 'Capacity', 
           'Priority', 'Default Tie-breaker Index', 'Tie-breaker Student Group Index', 
           'Advantage', 'Default Tie-breaker', 'Effective Tie-breaker', 'Assignment', 'Enrollment', 
           'Outcome 1', 'Outcome 2', 'Covariate 1', 'Covariate 2', 'Covariate 3']

# %%
# Create an empty list to store the data
data = []

# %%
# Loop through the years, grades, and schools to generate the data
count = 0
for year in years:
    for grade in grades:
        students = all_students[count*1000: (count+1)*1000]
        count += 1
        for student_index in students:
            student_id = student_index
            # Shuffle the list of school IDs to randomize the order
            school_ids = list(range(1, num_schools+1))
            random.shuffle(school_ids)
            # Take the first max_num_schools_per_student schools for this student
            school_ids = school_ids[:max_num_schools_per_student]
            
            # assignment 
            assigned_school = random.choice(school_ids)
            
            # enrollment
            if random.uniform(0,1) < 0.8:
                enrolled_school = assigned_school
            else:
                enrolled_school = random.choice(school_ids)

            # Loop through the school IDs and assign them to this student
            for rank, school_id in enumerate(school_ids):
                capacity = capacity_dict[school_id][year][grade] # Random capacity between 500 and 1000
                treatment = treatment_dict[school_id][year][grade] # Random treatment
                
                priority = random.randint(1, 5) # Random priority ranking 
                if random.uniform(0,1) < 0.05:
                    priority = 0
                
                default_tie_breaker_index = random.randint(1, num_tie_breakers) # Random default tie-breaker index
                tie_breaker_student_group_index = random.randint(0, 1) # Random tie-breaker student group index
                
                if tie_breaker_student_group_index == 0:
                    advantage = 0
                else:
                    advantage = advantage_dict[school_id][year][grade]
                
                default_tie_breaker = tie_dict[student_id][default_tie_breaker_index]
                effective_tie_breaker = default_tie_breaker * (1 - advantage)
                
                if school_id == assigned_school:
                    assignment = 1
                else:
                    assignment = 0
                
                if school_id == enrolled_school:
                    enrollment = 1
                else:
                    enrollment = 0
               
                outcome_1 = outcome_dict[student_id][0]
                outcome_2 = outcome_dict[student_id][1]
                covariate_1 = covariate_dict[student_id][0]
                covariate_2 = covariate_dict[student_id][1]
                covariate_3 = covariate3_dict[student_id][school_id]
                
                # Create a list of values for this row
                row = [student_id, year, grade, rank+1, school_id, treatment, capacity, 
                       priority, default_tie_breaker_index, tie_breaker_student_group_index, 
                       advantage, default_tie_breaker, effective_tie_breaker, assignment, 
                       enrollment, outcome_1, outcome_2, covariate_1, covariate_2, covariate_3]
                data.append(row)

# %%
df = pd.DataFrame(data, columns = columns)
df = df.sort_values(['Student ID', 'Choice Rank'])
df = df.reset_index(drop=True)
df.head()
# Out:
#    Student ID  Year  Grade  Choice Rank  School ID  Treatment  Capacity  \
# 0           1  2018      2            1         14          1        52
# 1           1  2018      2            2         13          1        50
# 2           1  2018      2            3          6          1        57
# 3           1  2018      2            4         23          1        51
# 4           1  2018      2            5         12          0        56
#
#    Priority  Default Tie-breaker Index  Tie-breaker Student Group Index  \
# 0         1                         13                                1
# 1         2                         20                                0
# 2         3                          4                                0
# 3         4                          6                                0
# 4         1                          4                                0
#
#    Advantage  Default Tie-breaker  Effective Tie-breaker  Assignment  \
# 0        0.1             0.716942               0.645247           1
# 1        0.0             0.090022               0.090022           0
# 2        0.0             0.994843               0.994843           0
# 3        0.0             0.481525               0.481525           0
# 4        0.0             0.994843               0.994843           0
#
#    Enrollment  Outcome 1  Outcome 2  Covariate 1  Covariate 2  Covariate 3
# 0           1         38          2           34           96           17
# 1           0         38          2           34           96          316
# 2           0         38          2           34           96          101
# 3           0         38          2           34           96          159
# 4           0         38          2           34           96          183

# %%
# Guaranteed assignment
for i in range(1, num_total_students+1):
    df_new = df.loc[df['Student ID'] == i]
    for j in df_new.index:
        if df.loc[j, 'Priority'] == 0:
            df.loc[j, 'Assignment'] = 1
            a = list(df_new.index)
            a.remove(j)
            for k in a:
                df.loc[k, 'Assignment'] = 0

# %%
# Capacity
over_assign = []
over_enroll = []
for n in range(1, num_schools+1):
    for y in years:
        for g in grades:
            if df.loc[(df['School ID'] == n) & (df['Year'] == y) & (df['Grade'] == g)]['Assignment'].sum() > capacity_dict[n][y][g]:
                over_assign.append((n,y,g))
            if df.loc[(df['School ID'] == n) & (df['Year'] == y) & (df['Grade'] == g)]['Enrollment'].sum() > capacity_dict[n][y][g]:
                over_enroll.append((n,y,g))

# %%
over_assign
# Out:
# [(6, 2018, 3), (15, 2018, 2), (16, 2018, 1)]

# %%
over_enroll
# Out:
# [(16, 2018, 1), (20, 2017, 3)]

# %%
df.to_excel('random.xlsx')

# %% [markdown]
# ## Check if it's (partly) clean

# %%
df.loc[(df['Priority'] == 0)]
# Out:
#        Student ID  Year  Grade  Choice Rank  School ID  Treatment  Capacity  \
# 36              8  2018      2            2          1          1        54
# 51             11  2018      3            2          6          0        51
# 59             12  2018      3            5         17          1        55
# 72             15  2017      1            3          6          0        48
# 77             16  2018      3            3          9          0        51
# ...           ...   ...    ...          ...        ...        ...       ...
# 29926        5986  2018      2            2         18          0        53
# 29935        5988  2018      3            1         13          1        54
# 29959        5992  2017      3            5          6          0        51
# 29995        6000  2017      3            1          6          0        51
# 29997        6000  2017      3            3         19          1        55
#
#        Priority  Default Tie-breaker Index  Tie-breaker Student Group Index  \
# 36            0                          6                                0
# 51            0                          3                                1
# 59            0                         19                                0
# 72            0                         20                                0
# 77            0                         20                                0
# ...         ...                        ...                              ...
# 29926         0                          6                                0
# 29935         0                         17                                0
# 29959         0                          7                                1
# 29995         0                          1                                1
# 29997         0                          9                                1
#
#        Advantage  Default Tie-breaker  Effective Tie-breaker  Assignment  \
# 36           0.0             0.963809               0.963809           1
# 51           0.5             0.167029               0.083514           1
# 59           0.0             0.063748               0.063748           0
# 72           0.0             0.447438               0.447438           0
# 77           0.0             0.133346               0.133346           0
# ...          ...                  ...                    ...         ...
# 29926        0.0             0.086855               0.086855           1
# 29935        0.0             0.001799               0.001799           1
# 29959        0.3             0.380747               0.266523           0
# 29995        0.3             0.337636               0.236345           1
# 29997        0.3             0.519159               0.363411           0
#
#        Enrollment  Outcome 1  Outcome 2  Covariate 1  Covariate 2  Covariate 3
# 36              0         65         91           98           18          261
# 51              0         57         81           35           52          298
# 59              0         19         24           34           89          449
# 72              0         56         92           63           14           24
# 77              0         21          6           50           45          146
# ...           ...        ...        ...          ...          ...          ...
# 29926           0         93         32            9           72          365
# 29935           0         56         71            2           33          100
# 29959           0         62         67           43           78          102
# 29995           1         65        100           42            4          178
# 29997           0         65        100           42            4          287
#
# [1512 rows x 20 columns]

# %%
df.loc[(df['School ID'] == 15) & (df['Year'] == 2017)]
# Out:
#        Student ID  Year  Grade  Choice Rank  School ID  Treatment  Capacity  \
# 8               2  2017      3            4         15          0        53
# 125            26  2017      1            1         15          1        54
# 248            50  2017      3            4         15          0        53
# 330            67  2017      1            1         15          1        54
# 368            74  2017      2            4         15          1        51
# ...           ...   ...    ...          ...        ...        ...       ...
# 29768        5954  2017      1            4         15          1        54
# 29844        5969  2017      3            5         15          0        53
# 29912        5983  2017      2            3         15          1        51
# 29955        5992  2017      1            1         15          1        54
# 29978        5996  2017      3            4         15          0        53
#
#        Priority  Default Tie-breaker Index  Tie-breaker Student Group Index  \
# 8             4                         18                                1
# 125           6                         15                                1
# 248           9                         14                                1
# 330           9                         13                                1
# 368           3                          3                                0
# ...         ...                        ...                              ...
# 29768         4                          4                                0
# 29844         5                         20                                1
# 29912         2                          6                                0
# 29955         8                          6                                1
# 29978         8                         14                                1
#
#        Advantage  Default Tie-breaker  Effective Tie-breaker  Assignment  \
# 8            0.1             0.686058               0.617453           0
# 125          0.5             0.464505               0.232252           1
# 248          0.1             0.505619               0.455057           1
# 330          0.5             0.694898               0.347449           0
# 368          0.0             0.870588               0.870588           0
# ...          ...                  ...                    ...         ...
# 29768        0.0             0.582798               0.582798           0
# 29844        0.1             0.773818               0.696436           0
# 29912        0.0             0.591010               0.591010           0
# 29955        0.5             0.042254               0.021127           0
# 29978        0.1             0.446052               0.401447           0
#
#        Enrollment  Outcome 1  Outcome 2  Covariate 1  Covariate 2  Covariate 3
# 8               0         99         61           74           76          359
# 125             1         51         87           82           19          111
# 248             1         45         65           85           37          155
# 330             0         98         20           23           36          321
# 368             0         91         88           66           27           97
# ...           ...        ...        ...          ...          ...          ...
# 29768           0         48         29           28           52          192
# 29844           0         72         49           16           72          314
# 29912           0         67         58           46           50          421
# 29955           0         99         21           79           92          268
# 29978           0         55         15           89           49          271
#
# [595 rows x 20 columns]

# %%
df.loc[(df['Student ID'] == 1502) & (df['Year'] == 2017)]
# Out:
#       Student ID  Year  Grade  Choice Rank  School ID  Treatment  Capacity  \
# 7505        1502  2017      3            1         19          0       657
# 7506        1502  2017      3            2         21          0       990
# 7507        1502  2017      3            3         25          0       954
# 7508        1502  2017      3            4          3          1       602
# 7509        1502  2017      3            5         24          1       887
#
#       Priority  Default Tie-breaker Index  Tie-breaker Student Group Index  \
# 7505         7                         15                                1
# 7506         6                         19                                0
# 7507        10                         19                                1
# 7508         2                         11                                1
# 7509         8                         16                                1
#
#       Advantage  Default Tie-breaker  Effective Tie-breaker  Assignment  \
# 7505        0.3             0.065687               0.045981           0
# 7506        0.0             0.137443               0.137443           1
# 7507        0.5             0.460700               0.230350           0
# 7508        0.3             0.787812               0.551468           0
# 7509        0.1             0.311524               0.280371           0
#
#       Enrollment  Outcome 1  Outcome 2  Covariate 1  Covariate 2  Covariate 3
# 7505           0         16         90           69            2           50
# 7506           0         16         90           69            2          144
# 7507           0         16         90           69            2          483
# 7508           0         16         90           69            2          247
# 7509           1         16         90           69            2           31

# %% [markdown]
# # 2. Create issues that result in errors / warnings

# %% [markdown]
# ## (erroneous cells are marked  red in the excel file)

# %% [markdown]
# ## (1) Inconsistency within a student

# %% [markdown]
# ### (1.1) Inconsistent grade within a student

# %% [markdown]
# Student ID 1 \
# Grade \
# index 2

# %% [markdown]
# ### (1.2) Inconsistent Outcomes within a student

# %% [markdown]
# Student ID 11 \
# Outcome 1 \
# index 50

# %% [markdown]
# ### (1.3) Inconsistent Default Tie-breaker within a (Student ID, Default Tie-breaker Index) pair

# %%
df.loc[(df['Student ID'] == 8)]
# Out:
#     Student ID  Year  Grade  Choice Rank  School ID  Treatment  Capacity  \
# 35           8  2017      1            1         22          1        54
# 36           8  2017      1            2         13          1        59
# 37           8  2017      1            3         11          0        59
# 38           8  2017      1            4         18          1        60
# 39           8  2017      1            5          8          0        58
#
#     Priority  Default Tie-breaker Index  Tie-breaker Student Group Index  \
# 35         1                          8                                0
# 36         1                         19                                0
# 37         1                         20                                0
# 38         3                          8                                1
# 39         2                         16                                1
#
#     Advantage  Default Tie-breaker  Effective Tie-breaker  Assignment  \
# 35        0.0             0.598726               0.598726           0
# 36        0.0             0.537666               0.537666           0
# 37        0.0             0.899058               0.899058           0
# 38        0.1             0.598726               0.538854           1
# 39        0.3             0.853363               0.597354           0
#
#     Enrollment  Outcome 1  Outcome 2  Covariate 1  Covariate 2  Covariate 3
# 35           0         52         23            9            6          139
# 36           0         52         23            9            6          223
# 37           0         52         23            9            6          493
# 38           1         52         23            9            6          220
# 39           0         52         23            9            6          373

# %% [markdown]
# Student ID 8 \
# Default Tie-breaker \
# index 38 and a lot more due to checkpoint #12 (correlation, orange mark in excel)

# %% [markdown]
# ## (2) Inconsistency within a (school, year, grade)

# %% [markdown]
# ### (2.1) Inconsistent Treatment value within a (School, Year, Grade)

# %%
df.loc[(df['School ID'] == 4) & (df['Year'] == 2017) & (df['Grade'] == 3)]
# Out:
#        Student ID  Year  Grade  Choice Rank  School ID  Treatment  Capacity  \
# 25              6  2017      3            1          4          1        51
# 60             13  2017      3            1          4          1        51
# 96             20  2017      3            2          4          1        51
# 115            24  2017      3            1          4          1        51
# 572           115  2017      3            3          4          1        51
# ...           ...   ...    ...          ...        ...        ...       ...
# 29587        5918  2017      3            3          4          1        51
# 29701        5941  2017      3            2          4          1        51
# 29735        5948  2017      3            1          4          1        51
# 29979        5996  2017      3            5          4          1        51
# 29990        5999  2017      3            1          4          1        51
#
#        Priority  Default Tie-breaker Index  Tie-breaker Student Group Index  \
# 25            2                         11                                1
# 60            0                         18                                0
# 96            1                         20                                0
# 115           3                          7                                0
# 572           4                         13                                0
# ...         ...                        ...                              ...
# 29587         2                         12                                0
# 29701         3                          5                                0
# 29735         4                          1                                1
# 29979         4                         17                                1
# 29990         3                          8                                0
#
#        Advantage  Default Tie-breaker  Effective Tie-breaker  Assignment  \
# 25           0.3             0.867018               0.606913           1
# 60           0.0             0.462623               0.462623           1
# 96           0.0             0.681404               0.681404           0
# 115          0.0             0.401073               0.401073           0
# 572          0.0             0.498610               0.498610           0
# ...          ...                  ...                    ...         ...
# 29587        0.0             0.529794               0.529794           0
# 29701        0.0             0.114234               0.114234           0
# 29735        0.3             0.074436               0.052105           0
# 29979        0.3             0.787875               0.551513           0
# 29990        0.0             0.662073               0.662073           0
#
#        Enrollment  Outcome 1  Outcome 2  Covariate 1  Covariate 2  Covariate 3
# 25              1         80         43           97           57          279
# 60              0         70          9           11           55          152
# 96              0         62         58            0           52          251
# 115             0         96         69           12           85          287
# 572             0         25         27           78           29          416
# ...           ...        ...        ...          ...          ...          ...
# 29587           0         74         30           44           79          115
# 29701           0         80         85            3            3          167
# 29735           0         17         59           17           91           63
# 29979           0         61          7           10           20          344
# 29990           0         10         70           40           17          241
#
# [205 rows x 20 columns]

# %% [markdown]
# School ID 4, 25 \
# Treatment \
# index 13, 25

# %% [markdown]
# ### (2.2) Inconsistent Capacity within a (School, Year, Grade)

# %%
df.loc[(df['School ID'] == 7) & (df['Year'] == 2018) & (df['Grade'] == 2)]
# Out:
#        Student ID  Year  Grade  Choice Rank  School ID  Treatment  Capacity  \
# 31              7  2018      2            2          7          1        50
# 274            55  2018      2            5          7          1        50
# 667           134  2018      2            3          7          1        50
# 817           164  2018      2            3          7          1        50
# 1361          273  2018      2            2          7          1        50
# ...           ...   ...    ...          ...        ...        ...       ...
# 29389        5878  2018      2            5          7          1        50
# 29593        5919  2018      2            4          7          1        50
# 29813        5963  2018      2            4          7          1        50
# 29901        5981  2018      2            2          7          1        50
# 29954        5991  2018      2            5          7          1        50
#
#        Priority  Default Tie-breaker Index  Tie-breaker Student Group Index  \
# 31            2                         13                                1
# 274           5                         15                                0
# 667           4                         13                                0
# 817           5                          8                                1
# 1361          3                         10                                1
# ...         ...                        ...                              ...
# 29389         4                         14                                0
# 29593         3                         14                                0
# 29813         0                         18                                1
# 29901         1                          5                                0
# 29954         1                         11                                0
#
#        Advantage  Default Tie-breaker  Effective Tie-breaker  Assignment  \
# 31           0.3             0.528189               0.369732           0
# 274          0.0             0.160429               0.160429           0
# 667          0.0             0.910433               0.910433           0
# 817          0.3             0.021589               0.015113           0
# 1361         0.3             0.832606               0.582824           0
# ...          ...                  ...                    ...         ...
# 29389        0.0             0.045618               0.045618           0
# 29593        0.0             0.739529               0.739529           0
# 29813        0.3             0.136353               0.095447           1
# 29901        0.0             0.056860               0.056860           0
# 29954        0.0             0.464896               0.464896           0
#
#        Enrollment  Outcome 1  Outcome 2  Covariate 1  Covariate 2  Covariate 3
# 31              0         88         19           42           83           80
# 274             0          6         31           38           95          144
# 667             1         27         45           36           29          133
# 817             0         97         43            9           23          374
# 1361            1         54         47           44            5          230
# ...           ...        ...        ...          ...          ...          ...
# 29389           0         32         96           71           70          266
# 29593           0         36         21           12            9          298
# 29813           1         26         62           62           63          223
# 29901           0         77         40           54           40          284
# 29954           0         71         51           80           14          223
#
# [199 rows x 20 columns]

# %% [markdown]
# School ID 7 \
# Capacity \
# index 31

# %% [markdown]
# ### (2.3) Inconsistent advantage within a (School, Year, Grade) pair

# %%
df.loc[(df['School ID'] == 16) & (df['Year'] == 2017) & (df['Grade'] == 1)]
# Out:
#        Unnamed: 0  Student ID  Year  Grade  Choice Rank  School ID  Treatment  \
# 40             40           9  2017      1            1         16          1
# 235           235          48  2017      1            1         16          1
# 406           406          82  2017      1            2         16          1
# 648           648         130  2017      1            4         16          1
# 881           881         177  2017      1            2         16          1
# ...           ...         ...   ...    ...          ...        ...        ...
# 28872       28872        5775  2017      1            3         16          1
# 28971       28971        5795  2017      1            2         16          1
# 29001       29001        5801  2017      1            2         16          1
# 29800       29800        5961  2017      1            1         16          1
# 29964       29964        5993  2017      1            5         16          1
#
#        Capacity  Priority  Default Tie-breaker Index  ...  Advantage  \
# 40           54         3                         14  ...        0.1
# 235          54         2                          6  ...        0.0
# 406          54         1                         13  ...        0.0
# 648          54         1                          9  ...        0.1
# 881          54         3                          4  ...        0.0
# ...         ...       ...                        ...  ...        ...
# 28872        54         1                         20  ...        0.0
# 28971        54         4                         19  ...        0.1
# 29001        54         4                         20  ...        0.1
# 29800        54         2                         17  ...        0.0
# 29964        54         5                         14  ...        0.1
#
#        Default Tie-breaker  Effective Tie-breaker  Assignment  Enrollment  \
# 40                0.530556               0.477500           0           0
# 235               0.480062               0.480062           0           0
# 406               0.381522               0.381522           1           0
# 648               0.665088               0.598579           0           0
# 881               0.228207               0.228207           0           0
# ...                    ...                    ...         ...         ...
# 28872             0.740661               0.740661           0           0
# 28971             0.854284               0.768855           1           1
# 29001             0.454356               0.408921           0           0
# 29800             0.849780               0.849780           0           0
# 29964             0.366460               0.329814           0           0
#
#        Outcome 1  Outcome 2  Covariate 1  Covariate 2  Covariate 3
# 40            70         78           76           47          311
# 235           24         42           84           30          113
# 406           14         84           86           13          278
# 648           84         48           99           32          488
# 881           30         18           70           94          317
# ...          ...        ...          ...          ...          ...
# 28872         68         66           27           17           76
# 28971         84         62           94           41          437
# 29001          2          3           85           70           94
# 29800         57         98           65           52          305
# 29964         73         50           76           11          308
#
# [213 rows x 21 columns]

# %% [markdown]
# School ID 16 \
# Advantage \
# index 40

# %% [markdown]
# ### (3) A student chose multiple schools for the same rank

# %% [markdown]
# Student ID 2, 3 \
# Choice Rank \
# index 6, 7, 12, 13

# %% [markdown]
# ### (4) A student chose the same school for multiple ranks

# %% [markdown]
# Student ID 3, 4 \
# School ID \
# index 12, 13, 15, 16

# %% [markdown]
# ### (5) Inconsecutive Choice Rank (e.g., 1,2,4)

# %% [markdown]
# Student ID 5 \
# Choice Rank \
# index 22, 23, 24

# %% [markdown]
# ## (6) Multiple Assignment / Enrollment

# %% [markdown]
# ### (6.1) A student is assigned to multiple schools

# %% [markdown]
# Student ID 12 \
# Assignment \
# index 55, 56

# %% [markdown]
# ### (6.2) A student is enrolled in multiple schools

# %% [markdown]
# Student ID 13 \
# Enrollment \
# index 60, 61

# %% [markdown]
# ## (7) Over capacity

# %% [markdown]
# ### (7.1) A (school, year, grade) is assigned with more students than its capacity and contains at least one student who is not guaranteed an assignment

# %%
over_assign
# Out:
# [(6, 2018, 3), (15, 2018, 2), (16, 2018, 1)]

# %%
df.loc[(df['School ID'] == 6) & (df['Year'] == 2018) & (df['Grade'] == 3)]
# Out:
#        Student ID  Year  Grade  Choice Rank  School ID  Treatment  Capacity  \
# 217            44  2018      3            3          6          1        50
# 386            78  2018      3            2          6          1        50
# 453            91  2018      3            4          6          1        50
# 622           125  2018      3            3          6          1        50
# 757           152  2018      3            3          6          1        50
# ...           ...   ...    ...          ...        ...        ...       ...
# 29254        5851  2018      3            5          6          1        50
# 29423        5885  2018      3            4          6          1        50
# 29566        5914  2018      3            2          6          1        50
# 29923        5985  2018      3            4          6          1        50
# 29940        5989  2018      3            1          6          1        50
#
#        Priority  Default Tie-breaker Index  Tie-breaker Student Group Index  \
# 217           2                          3                                1
# 386           3                          3                                1
# 453           2                         10                                1
# 622           2                         19                                0
# 757           5                          9                                1
# ...         ...                        ...                              ...
# 29254         4                         17                                0
# 29423         4                          6                                1
# 29566         5                          8                                0
# 29923         2                         19                                0
# 29940         1                         20                                0
#
#        Advantage  Default Tie-breaker  Effective Tie-breaker  Assignment  \
# 217          0.3             0.090120               0.063084           0
# 386          0.3             0.413344               0.289341           0
# 453          0.3             0.796559               0.557592           0
# 622          0.0             0.066137               0.066137           0
# 757          0.3             0.665987               0.466191           0
# ...          ...                  ...                    ...         ...
# 29254        0.0             0.846015               0.846015           1
# 29423        0.3             0.994395               0.696076           0
# 29566        0.0             0.931282               0.931282           0
# 29923        0.0             0.874382               0.874382           1
# 29940        0.0             0.615807               0.615807           0
#
#        Enrollment  Outcome 1  Outcome 2  Covariate 1  Covariate 2  Covariate 3
# 217             0         11         67           88           44          154
# 386             0         60         22           38           71          190
# 453             0         28         84           54           29          424
# 622             1         61         54           66           37          403
# 757             0         71         91           50           94           79
# ...           ...        ...        ...          ...          ...          ...
# 29254           1         38         30           89          100          347
# 29423           0         45         63           91           57          305
# 29566           0         42         16           65           92          145
# 29923           0         27         93           98           80          307
# 29940           0         85          2           98           48          107
#
# [205 rows x 20 columns]

# %%
df.loc[(df['School ID'] == 6) & (df['Year'] == 2018) & (df['Grade'] == 3)]['Assignment'].sum()
# Out:
# 52

# %% [markdown]
# Most of people have non-zero priority.

# %% [markdown]
# Thus, Stata should return the 3 schools (6, 15, 16) in the over_assign list.

# %% [markdown]
# ### (7.2) A (school, year, grade) pair is enrolled by more students than its capacity and contains at least one student who is not guaranteed an assignment

# %%
over_enroll
# Out:
# [(16, 2018, 1), (20, 2017, 3)]

# %% [markdown]
# Stata should return these two schools

# %% [markdown]
# ### (8) A student is not assigned to a school although the student was guaranteed an assignment to that school and she was not assigned to any school she prefers to that school.

# %% [markdown]
# Student ID 15 \
# Assignment \
# index 74

# %% [markdown]
# ### (9) A student is assigned to school s, even though (1) she prefers school s' to s, (2) her applicant position at s' was better than her position at s, (3) there were still available spots at s', (4) and she is eligible at s'

# %% [markdown]
# There should be a lot of cases of this. The following case should be included: \
# Student ID 16 \
# School ID 15 \
# while she prefers school 3, 24 and her applicant position is better at those schools. \
# Assignment \
# index 78

# %% [markdown]
# ### (10) Abnormally large value (e.g., greater than 10 × mean of that column) found in a column that is unlikely to have a huge outlier

# %% [markdown]
# Student ID 18 \
# Grade \
# index 85-89

# %% [markdown]
# ### (11) A school uses non-lottery tie-breaker, and correlation between Priority and Tie-breaker within the (school, year, grade) approximates 1

# %% [markdown]
# School ID 1 \
# Year 2017 \
# Grade 1 \
# Orange
